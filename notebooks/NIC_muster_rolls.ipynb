# %%
import requests
import pandas as pd
#from bs4 import BeautifulSoup
from bs4 import BeautifulSoup, NavigableString, Tag
from slugify import slugify

# %% [markdown]
# # NIC Muster Rolls

# %%
url = 'http://nregasp2.nic.in/netnrega/Citizen_html/Musternew.aspx'
print('Fetching URL[%s] for cookies' % url)

session = requests.Session()
#with requests.Session() as session:
response = session.get(url)
cookies = session.cookies
print(cookies)

soup = ''

VIEWSTATE=''
EVENTVALIDATION=''
#EVENTTARGET=soup.find(id="__EVENTTARGET")['value']
#EVENTARGUEMENT=soup.find(id="__EVENTARGUMENT")['value']

work_codes = []
muster_nos = []

# %%
headers = {
    'Connection': 'keep-alive',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.142 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Language': 'en-US,en;q=0.9',
}

params = (
    ('id', '2'),
    ('lflag', 'eng'),
    ('ExeL', 'GP'),
    ('fin_year', '2020-2021'),
    ('state_code', '34'),
    ('district_code', '3424'),
    ('block_code', '3401020'),
    ('panchayat_code', '3401020002'),
    ('State_name', 'JHARKHAND'),
    ('District_name', 'KHUNTI'),
    ('Block_name', 'TORPA'),
    ('panchayat_name', 'BARKULI'),
    ('Digest', 'Q CEdRMQ8m7Jfvp6sBSfzg'),
)

response = session.get('http://nregasp2.nic.in/netnrega/Citizen_html/Musternew.aspx', headers=headers, params=params, cookies=cookies, verify=False)
print(response)
soup = BeautifulSoup(response.text, 'lxml')
VIEWSTATE=soup.find(id="__VIEWSTATE")['value']
EVENTVALIDATION=soup.find(id="__EVENTVALIDATION")['value']

# %%
headers = {
    'Connection': 'keep-alive',
    'Cache-Control': 'max-age=0',
    'Upgrade-Insecure-Requests': '1',
    'Origin': 'http://nregasp2.nic.in',
    'Content-Type': 'application/x-www-form-urlencoded',
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.142 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Referer': 'http://nregasp2.nic.in/netnrega/Citizen_html/Musternew.aspx?id=2&lflag=eng&ExeL=GP&fin_year=2020-2021&state_code=34&district_code=3424&block_code=3401020&panchayat_code=3401020002&State_name=JHARKHAND&District_name=KHUNTI&Block_name=TORPA&panchayat_name=BARKULI&Digest=Q+CEdRMQ8m7Jfvp6sBSfzg',
    'Accept-Language': 'en-US,en;q=0.9',
}

params = (
    ('id', '2'),
    ('lflag', 'eng'),
    ('ExeL', 'GP'),
    ('fin_year', '2020-2021'),
    ('state_code', '34'),
    ('district_code', '3424'),
    ('block_code', '3401020'),
    ('panchayat_code', '3401020002'),
    ('State_name', 'JHARKHAND'),
    ('District_name', 'KHUNTI'),
    ('Block_name', 'TORPA'),
    ('panchayat_name', 'BARKULI'),
    ('Digest', 'Q CEdRMQ8m7Jfvp6sBSfzg'),
)

data = {
    '__EVENTTARGET': 'ctl00$ContentPlaceHolder1$ddlFinYear',
    '__EVENTARGUMENT': '',
    '__LASTFOCUS': '',
    '__VIEWSTATE': VIEWSTATE,
    '__EVENTVALIDATION': EVENTVALIDATION,
    'ctl00$ContentPlaceHolder1$ddlFinYear': '2019-2020',
    'ctl00$ContentPlaceHolder1$btnfill': 'btnfill',
    'ctl00$ContentPlaceHolder1$txtSearch': '',
    'ctl00$ContentPlaceHolder1$ddlwork': '---select---',
    'ctl00$ContentPlaceHolder1$ddlMsrno': '---select---'
}

response = session.post('http://nregasp2.nic.in/netnrega/Citizen_html/Musternew.aspx', headers=headers, params=params, cookies=cookies, data=data, verify=False)
print(response)
soup = BeautifulSoup(response.text, 'lxml')
VIEWSTATE=soup.find(id="__VIEWSTATE")['value']
EVENTVALIDATION=soup.find(id="__EVENTVALIDATION")['value']

# %%
headers = {
    'Connection': 'keep-alive',
    'Cache-Control': 'max-age=0',
    'Upgrade-Insecure-Requests': '1',
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.142 Safari/537.36',
    'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
    'Accept-Language': 'en-US,en;q=0.9',
}

params = (
    ('id', '2'),
    ('lflag', 'eng'),
    ('ExeL', 'GP'),
    ('fin_year', '2020-2021'),
    ('state_code', '34'),
    ('district_code', '3424'),
    ('block_code', '3401020'),
    ('panchayat_code', '3401020002'),
    ('State_name', 'JHARKHAND'),
    ('District_name', 'KHUNTI'),
    ('Block_name', 'TORPA'),
    ('panchayat_name', 'BARKULI'),
    ('Digest', 'Q CEdRMQ8m7Jfvp6sBSfzg'),
)

response = session.get('http://nregasp2.nic.in/netnrega/Citizen_html/Musternew.aspx', headers=headers, params=params, cookies=cookies, verify=False)
print(response)

soup = BeautifulSoup(response.text, 'lxml')
VIEWSTATE=soup.find(id="__VIEWSTATE")['value']
EVENTVALIDATION=soup.find(id="__EVENTVALIDATION")['value']

work_names_html = soup.find(id='ctl00_ContentPlaceHolder1_ddlwork')

work_codes = []
for body_child in work_names_html:
    if isinstance(body_child, NavigableString):
        #print(f'NavigableString[{body_child}]')
        continue
    if isinstance(body_child, Tag):
        work_code = body_child['value']
        print(work_code)
        if('---select---' in work_code):
            continue
        work_codes.append(work_code)
        break
    #print(work_name_html)
print(work_codes)

# %%
headers = {
    'Connection': 'keep-alive',
    'Cache-Control': 'no-cache',
    'X-MicrosoftAjax': 'Delta=true',
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.142 Safari/537.36',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'Accept': '*/*',
    'Origin': 'http://nregasp2.nic.in',
    'Referer': 'http://nregasp2.nic.in/netnrega/Citizen_html/Musternew.aspx?id=2&lflag=eng&ExeL=GP&fin_year=2020-2021&state_code=34&district_code=3424&block_code=3401020&panchayat_code=3401020002&State_name=JHARKHAND&District_name=KHUNTI&Block_name=TORPA&panchayat_name=BARKULI&Digest=Q+CEdRMQ8m7Jfvp6sBSfzg',
    'Accept-Language': 'en-US,en;q=0.9',
}

params = (
    ('id', '2'),
    ('lflag', 'eng'),
    ('ExeL', 'GP'),
    ('fin_year', '2020-2021'),
    ('state_code', '34'),
    ('district_code', '3424'),
    ('block_code', '3401020'),
    ('panchayat_code', '3401020002'),
    ('State_name', 'JHARKHAND'),
    ('District_name', 'KHUNTI'),
    ('Block_name', 'TORPA'),
    ('panchayat_name', 'BARKULI'),
    ('Digest', 'Q CEdRMQ8m7Jfvp6sBSfzg'),
)

data = {
  'ctl00$ContentPlaceHolder1$ScriptManager1': 'ctl00$ContentPlaceHolder1$ScriptManager1|ctl00$ContentPlaceHolder1$ddlwork',
  '__EVENTTARGET': 'ctl00$ContentPlaceHolder1$ddlwork',
  '__EVENTARGUMENT': '',
  '__LASTFOCUS': '',
  '__VIEWSTATE': VIEWSTATE,
  '__EVENTVALIDATION': EVENTVALIDATION,
  'ctl00$ContentPlaceHolder1$ddlFinYear': '2020-2021',
  'ctl00$ContentPlaceHolder1$btnfill': 'btnfill',
  'ctl00$ContentPlaceHolder1$txtSearch': '',
  'ctl00$ContentPlaceHolder1$ddlwork': work_code,
  'ctl00$ContentPlaceHolder1$ddlMsrno': '---select---',
  '__ASYNCPOST': 'true',
  '': ''
}

response = session.post('http://nregasp2.nic.in/netnrega/Citizen_html/Musternew.aspx', headers=headers, params=params, cookies=cookies, data=data, verify=False)
print(response)
soup = BeautifulSoup(response.text, 'lxml')
#print(soup)
# Update the context
body = soup.find('body')
#logger.warning(body.text)
array = body.text.split('|')
VIEWSTATE = array[array.index('__VIEWSTATE')+1]
#logger.debug(self.view_state)
EVENTVALIDATION = array[array.index('__EVENTVALIDATION')+1]
#logger.debug(self.event_validation)

muster_nos_dd = soup.find(id='ctl00_ContentPlaceHolder1_ddlMsrno')
print(muster_nos_dd)
muster_nos = []
for body_child in muster_nos_dd:
    if isinstance(body_child, NavigableString):
        continue
    if isinstance(body_child, Tag):
        muster_no = body_child['value']
        print(muster_no)
        if('---Select---' in muster_no):
            continue
        muster_nos.append(muster_no)
        break

print(muster_nos)

# %%
headers = {
    'Connection': 'keep-alive',
    'Cache-Control': 'no-cache',
    'X-MicrosoftAjax': 'Delta=true',
    'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.142 Safari/537.36',
    'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
    'Accept': '*/*',
    'Origin': 'http://nregasp2.nic.in',
    'Referer': 'http://nregasp2.nic.in/netnrega/Citizen_html/Musternew.aspx?id=2&lflag=eng&ExeL=GP&fin_year=2020-2021&state_code=34&district_code=3424&block_code=3401020&panchayat_code=3401020002&State_name=JHARKHAND&District_name=KHUNTI&Block_name=TORPA&panchayat_name=BARKULI&Digest=Q+CEdRMQ8m7Jfvp6sBSfzg',
    'Accept-Language': 'en-US,en;q=0.9',
}

params = (
    ('id', '2'),
    ('lflag', 'eng'),
    ('ExeL', 'GP'),
    ('fin_year', '2020-2021'),
    ('state_code', '34'),
    ('district_code', '3424'),
    ('block_code', '3401020'),
    ('panchayat_code', '3401020002'),
    ('State_name', 'JHARKHAND'),
    ('District_name', 'KHUNTI'),
    ('Block_name', 'TORPA'),
    ('panchayat_name', 'BARKULI'),
    ('Digest', 'Q CEdRMQ8m7Jfvp6sBSfzg'),
)

data = {
  'ctl00$ContentPlaceHolder1$ScriptManager1': 'ctl00$ContentPlaceHolder1$UpdatePanel2|ctl00$ContentPlaceHolder1$ddlMsrno',
  'ctl00$ContentPlaceHolder1$ddlFinYear': '2020-2021',
  'ctl00$ContentPlaceHolder1$btnfill': 'btnfill',
  'ctl00$ContentPlaceHolder1$txtSearch': '',
  'ctl00$ContentPlaceHolder1$ddlwork': work_code,
  'ctl00$ContentPlaceHolder1$ddlMsrno': muster_no,
  '__EVENTTARGET': 'ctl00$ContentPlaceHolder1$ddlMsrno',
  '__EVENTARGUMENT': '',
  '__LASTFOCUS': '',
  '__VIEWSTATE': VIEWSTATE,
  '__EVENTVALIDATION': EVENTVALIDATION,
  '__ASYNCPOST': 'true',
  '': ''
}

response = session.post('http://nregasp2.nic.in/netnrega/Citizen_html/Musternew.aspx', headers=headers, params=params, cookies=cookies, data=data, verify=False)

filename = '../Data/NIC/' + slugify(f'{work_code}_{muster_no}') + '.html'
with open(filename, 'wb') as output:
    print(f'Writing file[{filename}]')
    output.write(response.content)
print(response)

# %% [markdown]
# ## Using Functions

# %%
import requests
import pandas as pd
from bs4 import BeautifulSoup, NavigableString, Tag
from slugify import slugify

url = 'http://nregasp2.nic.in/netnrega/Citizen_html/Musternew.aspx'
print('Fetching URL[%s] for cookies' % url)

session = requests.Session()
response = session.get(url)
cookies = session.cookies
print(cookies)

soup = ''

VIEWSTATE=''
EVENTVALIDATION=''

work_codes = []
muster_nos = []

# %%
def set_finyear():
    headers = {
       'Connection': 'keep-alive',
        'Upgrade-Insecure-Requests': '1',
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.142 Safari/537.36',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'Accept-Language': 'en-US,en;q=0.9',
    }

    params = (
        ('id', '2'),
        ('lflag', 'eng'),
        ('ExeL', 'GP'),
        ('fin_year', '2020-2021'),
        ('state_code', '34'),
        ('district_code', '3424'),
        ('block_code', '3401020'),
        ('panchayat_code', '3401020002'),
        ('State_name', 'JHARKHAND'),
        ('District_name', 'KHUNTI'),
        ('Block_name', 'TORPA'),
        ('panchayat_name', 'BARKULI'),
        ('Digest', 'Q CEdRMQ8m7Jfvp6sBSfzg'),
    )

    response = session.get('http://nregasp2.nic.in/netnrega/Citizen_html/Musternew.aspx', headers=headers, params=params, cookies=cookies, verify=False)
    print(response)
    soup = BeautifulSoup(response.text, 'lxml')
    VIEWSTATE=soup.find(id="__VIEWSTATE")['value']
    EVENTVALIDATION=soup.find(id="__EVENTVALIDATION")['value']

# %%
def fetch_work_codes():
    headers = {
        'Connection': 'keep-alive',
        'Cache-Control': 'max-age=0',
        'Upgrade-Insecure-Requests': '1',
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.142 Safari/537.36',
        'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/webp,image/apng,*/*;q=0.8,application/signed-exchange;v=b3;q=0.9',
        'Accept-Language': 'en-US,en;q=0.9',
    }

    params = (
        ('id', '2'),
        ('lflag', 'eng'),
        ('ExeL', 'GP'),
        ('fin_year', '2020-2021'),
        ('state_code', '34'),
        ('district_code', '3424'),
        ('block_code', '3401020'),
        ('panchayat_code', '3401020002'),
        ('State_name', 'JHARKHAND'),
        ('District_name', 'KHUNTI'),
        ('Block_name', 'TORPA'),
        ('panchayat_name', 'BARKULI'),
        ('Digest', 'Q CEdRMQ8m7Jfvp6sBSfzg'),
    )

    response = session.get('http://nregasp2.njahnaviic.in/netnrega/Citizen_html/Musternew.aspx', headers=headers, params=params, cookies=cookies, verify=False)
    print(response)
    
    soup = BeautifulSoup(response.text, 'lxml')
    VIEWSTATE=soup.find(id="__VIEWSTATE")['value']
    EVENTVALIDATION=soup.find(id="__EVENTVALIDATION")['value']

    work_names_html = soup.find(id='ctl00_ContentPlaceHolder1_ddlwork')
    
    work_codes = []
    for body_child in work_names_html:
        if isinstance(body_child, NavigableString):
            #print(f'NavigableString[{body_child}]')
            continue
        if isinstance(body_child, Tag):
            work_code = body_child['value']
            print(work_code)
            if('---select---' in work_code):
                continue
            work_codes.append(work_code)
            break
        #print(work_name_html)
    return work_codes

#print(fetch_work_codes())

# %%
def fetch_muster_numbers(work_code, VIEWSTATE, EVENTVALIDATION):
    headers = {
        'Connection': 'keep-alive',
        'Cache-Control': 'no-cache',
        'X-MicrosoftAjax': 'Delta=true',
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.142 Safari/537.36',
        'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
        'Accept': '*/*',
        'Origin': 'http://nregasp2.nic.in',
        'Referer': 'http://nregasp2.nic.in/netnrega/Citizen_html/Musternew.aspx?id=2&lflag=eng&ExeL=GP&fin_year=2020-2021&state_code=34&district_code=3424&block_code=3401020&panchayat_code=3401020002&State_name=JHARKHAND&District_name=KHUNTI&Block_name=TORPA&panchayat_name=BARKULI&Digest=Q+CEdRMQ8m7Jfvp6sBSfzg',
        'Accept-Language': 'en-US,en;q=0.9',
    }

    params = (
        ('id', '2'),
        ('lflag', 'eng'),
        ('ExeL', 'GP'),
        ('fin_year', '2020-2021'),
        ('state_code', '34'),
        ('district_code', '3424'),
        ('block_code', '3401020'),
        ('panchayat_code', '3401020002'),
        ('State_name', 'JHARKHAND'),
        ('District_name', 'KHUNTI'),
        ('Block_name', 'TORPA'),
        ('panchayat_name', 'BARKULI'),
        ('Digest', 'Q CEdRMQ8m7Jfvp6sBSfzg'),
    )

    data = {
      'ctl00$ContentPlaceHolder1$ScriptManager1': 'ctl00$ContentPlaceHolder1$ScriptManager1|ctl00$ContentPlaceHolder1$ddlwork',
      '__EVENTTARGET': 'ctl00$ContentPlaceHolder1$ddlwork',
      '__EVENTARGUMENT': '',
      '__LASTFOCUS': '',
      '__VIEWSTATE': VIEWSTATE,
      '__EVENTVALIDATION': EVENTVALIDATION,
      'ctl00$ContentPlaceHolder1$ddlFinYear': '2020-2021',
      'ctl00$ContentPlaceHolder1$btnfill': 'btnfill',
      'ctl00$ContentPlaceHolder1$txtSearch': '',
      'ctl00$ContentPlaceHolder1$ddlwork': work_code,
      'ctl00$ContentPlaceHolder1$ddlMsrno': '---select---',
      '__ASYNCPOST': 'true',
      '': ''
    }

    response = session.post('http://nregasp2.nic.in/netnrega/Citizen_html/Musternew.aspx', headers=headers, params=params, cookies=cookies, data=data, verify=False)
    print(response)
    soup = BeautifulSoup(response.text, 'lxml')
    print(soup)
    muster_nos_dd = soup.find(id='ctl00_ContentPlaceHolder1_ddlMsrno')
    print(muster_nos_dd)
    muster_nos = []
    for body_child in muster_nos_dd:
        if isinstance(body_child, NavigableString):
            continue
        if isinstance(body_child, Tag):
            muster_no = body_child['value']
            print(muster_no)
            if('---Select---' in muster_no):
                continue
            muster_nos.append(muster_no)
            break

    return muster_nos

# %%
print(fetch_muster_numbers('3401020001/IF/7080901025854', VIEWSTATE, EVENTVALIDATION))

# %%
def fetch_muster_roll(work_code, muster_no, VIEWSTATE, EVENTVALIDATION):
    headers = {
        'Connection': 'keep-alive',
        'Cache-Control': 'no-cache',
        'X-MicrosoftAjax': 'Delta=true',
        'User-Agent': 'Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/81.0.4044.142 Safari/537.36',
        'Content-Type': 'application/x-www-form-urlencoded; charset=UTF-8',
        'Accept': '*/*',
        'Origin': 'http://nregasp2.nic.in',
        'Referer': 'http://nregasp2.nic.in/netnrega/Citizen_html/Musternew.aspx?id=2&lflag=eng&ExeL=GP&fin_year=2020-2021&state_code=34&district_code=3424&block_code=3401020&panchayat_code=3401020002&State_name=JHARKHAND&District_name=KHUNTI&Block_name=TORPA&panchayat_name=BARKULI&Digest=Q+CEdRMQ8m7Jfvp6sBSfzg',
        'Accept-Language': 'en-US,en;q=0.9',
    }

    params = (
        ('id', '2'),
        ('lflag', 'eng'),
        ('ExeL', 'GP'),
        ('fin_year', '2020-2021'),
        ('state_code', '34'),
        ('district_code', '3424'),
        ('block_code', '3401020'),
        ('panchayat_code', '3401020002'),
        ('State_name', 'JHARKHAND'),
        ('District_name', 'KHUNTI'),
        ('Block_name', 'TORPA'),
        ('panchayat_name', 'BARKULI'),
        ('Digest', 'Q CEdRMQ8m7Jfvp6sBSfzg'),
    )

    data = {
      'ctl00$ContentPlaceHolder1$ScriptManager1': 'ctl00$ContentPlaceHolder1$UpdatePanel2|ctl00$ContentPlaceHolder1$ddlMsrno',
      'ctl00$ContentPlaceHolder1$ddlFinYear': '2020-2021',
      'ctl00$ContentPlaceHolder1$btnfill': 'btnfill',
      'ctl00$ContentPlaceHolder1$txtSearch': '',
      'ctl00$ContentPlaceHolder1$ddlwork': work_code,
      'ctl00$ContentPlaceHolder1$ddlMsrno': muster_no,
      '__EVENTTARGET': 'ctl00$ContentPlaceHolder1$ddlMsrno',
      '__EVENTARGUMENT': '',
      '__LASTFOCUS': '',
      '__VIEWSTATE': VIEWSTATE,
      '__EVENTVALIDATION': EVENTVALIDATION,
      '__ASYNCPOST': 'true',
      '': ''
    }

    response = session.post('http://nregasp2.nic.in/netnrega/Citizen_html/Musternew.aspx', headers=headers, params=params, cookies=cookies, data=data, verify=False)

    filename = '../Data/' + slugify(f'{work_code}_{muster_no}.html')
    with open(filename, 'wb') as output:
        print(f'Writing file[{filename}]')
        output.write(response.content)

    return response.content

# %%
set_finyear()

# %%
work_codes = fetch_work_codes()

# %%
for work_code in work_codes:
    muster_nos = fetch_muster_numbers(work_code, VIEWSTATE, EVENTVALIDATION)
    for muster_no in muster_nos:
        html_content = fetch_muster_roll(work_code, muster_no, VIEWSTATE, EVENTVALIDATION)
        print(html_content)
        exit(0)
    exit(0)
